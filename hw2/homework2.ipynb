# %% [markdown]
# # Homework 2
#
# **The following notebook is meant to help you work through Problems 1 and 3 on Homework 2. You are by no means required to use it, nor are you required to fill out/use any of the boilerplate code/functions. You are welcome to implement the functions however you wish.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as c
import matplotlib.patches as mpatches
from scipy.special import expit as sigmoid
from scipy.special import softmax
from scipy.special import logsumexp

# %%
# loading data

# data for Problem 1
t_obs, y_obs = np.genfromtxt("data/planet-obs.csv", delimiter = ',').T
t_obs = np.split(t_obs, 10)
y_obs = np.split(y_obs.reshape(-1, 1), 10)

# data for Problem 3
data = pd.read_csv("data/hr.csv")
mapper = {
    "Dwarf": 0,
    "Giant": 1,
    "Supergiant": 2
}
data['Type'] = data['Type'].map(mapper)

X_stars = data[['Magnitude', 'Temperature']].values
y_stars = data['Type'].values

from T2_P1_TestCases import test_p1
from T2_P3_TestCases import test_p3_softmax, test_p3_knn

# %% [markdown]
# # Problem 1

# %% [markdown]
# ## Problem 1 Subpart 1

# %%
def basis1(t):
    return np.stack([np.ones(len(t)), t], axis=1)

def basis2(t):  
    return np.stack([np.ones(len(t)), t, t**2], axis=1)

def basis3(t):
    return np.stack([np.ones(len(t)), t, t**2, t**3, t**4, t**5], axis=1)

# %%
class LogisticRegressor:
    def __init__(self, eta, runs):
        self.eta = eta
        self.runs = runs
        self.W = None

    def fit(self, x, y, w_init):
        # Keep this for the autograder
        self.W = w_init
        # TODO
        n = x.shape[0]

        for run in range(self.runs): 
            y_pred = self.predict(x)
            gradient = np.dot(x.T, (y_pred - y)) / n
            self.W -= self.eta * gradient

    def predict(self, x):
        z = np.dot(x,self.W)
        probs = sigmoid(z)
        return probs

# %%
test_p1(LogisticRegressor, basis1, basis2, basis3)
# Out:
# Your test case results are, for basis 1, 2, and 3 respectively: Pass Pass Pass

# %% [markdown]
# Note: Students have reported local issues with passing the basis 3 test case. Try running on Google Colab if only basis 3 test is failing.

# %% [markdown]
# ## Plotting Functions for Problem 1, Subpart 2

# %%
# Function to visualize prediction lines
# Takes as input last_x, last_y, [list of models], basis function, title
# last_x and last_y should specifically be the dataset that the last model
# in [list of models] was trained on
def visualize_prediction_lines(last_x, last_y, models, basis, title):
    # Plot setup
    green = mpatches.Patch(color='green', label='Ground truth model')
    black = mpatches.Patch(color='black', label='Mean of learned models')
    purple = mpatches.Patch(color='purple', label='Model learned from displayed dataset')
    plt.legend(handles=[green, black, purple], loc='lower right')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Observed')
    plt.axis([0, 6, -.1, 1.1]) # Plot ranges

    # Plot dataset that last model in models (models[-1]) was trained on
    cmap = c.ListedColormap(['r', 'b'])
    plt.scatter(last_x, last_y, c=last_y, cmap=cmap, linewidths=1, edgecolors='black')

    # Plot models
    X_pred = np.linspace(0, 6, 1000)
    X_pred_transformed = basis(X_pred)

    ## Ground truth model
    plt.plot(X_pred, np.cos(1.1*X_pred + 1) * 0.4 + 0.5, 'g', linewidth=5)

    ## Individual learned logistic regressor models
    Y_hats = []
    for i in range(len(models)):
        model = models[i]
        Y_hat = model.predict(X_pred_transformed)
        Y_hats.append(Y_hat)
        if i < len(models) - 1:
            plt.plot(X_pred, Y_hat, linewidth=.3)
        else:
            plt.plot(X_pred, Y_hat, 'purple', linewidth=3)

    # Mean / expectation of learned models over all datasets
    plt.plot(X_pred, np.mean(Y_hats, axis=0), 'k', linewidth=5)

    plt.savefig(title + '.png')
    plt.show()

# %%
# You may find it helpful to modify this function for Problem 1, Subpart 4,
# but do not change the existing code--add your own variables
def plot_results(basis, title):
    eta = 0.001
    runs = 10000
    test_points = [0.1, 3.2]
    
    all_models = []
    for i in range(10):
        x, y = t_obs[i], y_obs[i]
        x_transformed = basis(x)
        model = LogisticRegressor(eta=eta, runs=runs)
        model.fit(x_transformed, y, np.zeros((x_transformed.shape[1], 1)))
        all_models.append(model)
    

    visualize_prediction_lines(x, y, all_models, basis, title)

# %%
plot_results(basis1, 'basis1')
plot_results(basis2, 'basis2')
plot_results(basis3, 'basis3')

# %% [markdown]
# # Problem 3

# %%
class GaussianGenerativeModel:
    def __init__(self, is_shared_covariance=False):
        self.is_shared_covariance = is_shared_covariance

    def fit(self, X, y):
        """
        Compute the means and (shared) covariance matrix of the data. Compute the prior over y.
        
        :param X: a 2D numpy array of (transformed) feature values. Shape is (n x 2)
        :param y: a 1D numpy array of target values (Dwarf=0, Giant=1, Supergiant=2).
        :return: None
        """
        # TODO
        self.class_means = np.array([np.mean(X[y == c], axis=0) for c in range(3)])
        if self.is_shared_covariance:
            self.covariance_matrix = np.cov(X.T)
        else:
            self.covariance_matrix = np.array([np.cov(X[y == c].T) for c in range(3)])
        self.class_priors = np.array([np.mean(y == c) for c in range(3)])

    def predict(self, X_pred):
        """
        The code in this method should be removed and replaced! We included it
        just so that the distribution code is runnable and produces a
        (currently meaningless) visualization.
        
        Predict classes of points given feature values in X_pred
        
        :param X_pred: a 2D numpy array of (transformed) feature values. Shape is (n x 2)
        :return: a 1D numpy array of predicted classes (Dwarf=0, Giant=1, Supergiant=2).
                 Shape should be (n,)
        """
        n = X_pred.shape[0]
        num_classes = len(self.class_means)
        if self.is_shared_covariance:
            # Shared covariance matrix
            inv_cov = np.linalg.inv(self.covariance_matrix)
            log_probs = np.zeros((n, num_classes))
            for i in range(num_classes):
                diff = X_pred - self.class_means[i]
                log_probs[:, i] = -0.5 * np.sum(diff @ inv_cov * diff, axis=1) + \
                                   np.log(self.class_priors[i])
        else:
            # Separate covariance matrices
            log_probs = np.zeros((n, num_classes))
            for i in range(num_classes):
                inv_cov = np.linalg.inv(self.covariance_matrix[i])
                diff = X_pred - self.class_means[i]
                log_probs[:, i] = -0.5 * np.sum(diff @ inv_cov * diff, axis=1) + \
                                   np.log(self.class_priors[i])
        return np.argmax(log_probs, axis=1)
        # TODO

    def negative_log_likelihood(self, X, y):
        """
        Given the data X, use previously calculated class means and covariance matrix to 
        calculate the negative log likelihood of the data
        """
        nll = 0
        num_classes = len(self.class_means)
        for i in range(num_classes):
            if self.is_shared_covariance:
                inv_cov = np.linalg.inv(self.covariance_matrix)
            else:
                inv_cov = np.linalg.inv(self.covariance_matrix[i])
            diff = X - self.class_means[i]
            nll -= np.sum(np.log(np.sqrt(2 * np.pi * np.linalg.det(inv_cov))) +
                          0.5 * np.sum((diff @ inv_cov) * diff, axis=1))
        return nll
        pass

# %%
class SoftmaxRegression:
    def __init__(self, eta, lam):
        self.eta = eta
        self.lam = lam
        self.W = None

    def fit(self, X, y):
        """
        Fit the weights W of softmax regression using gradient descent with L2 regularization
        Use the results from Problem 2 to find an expression for the gradient
        
        :param X: a 2D numpy array of (transformed) feature values. Shape is (n x 2)
        :param y: a 1D numpy array of target values (Dwarf=0, Giant=1, Supergiant=2).
        :return: None
        """
        # Initializing the weights (do not change!)
        # The number of classes is 1 + (the highest numbered class)
        num_classes = 1 + y.max()
        num_features = X.shape[1]
        self.W = np.ones((num_classes, num_features))
        # TODO
        for _ in range(200000):
            # Compute softmax probabilities
            scores = np.dot(X, self.W.T)
            exp_scores = np.exp(scores)
            probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
            
            # Compute gradient of loss function with L2 regularization
            grad = np.zeros_like(self.W)
            for i in range(len(X)):
                for j in range(num_classes):
                    grad[j] += (probs[i][j] - (y[i] == j)) * X[i]
            grad += self.lam * self.W
            self.W -= self.eta * grad

    def predict(self, X_pred):
        """
        The code in this method should be removed and replaced! We included it
        just so that the distribution code is runnable and produces a
        (currently meaningless) visualization.
        
        Predict classes of points given feature values in X_pred
        
        :param X_pred: a 2D numpy array of (transformed) feature values. Shape is (n x 2)
        :return: a 1D numpy array of predicted classes (Dwarf=0, Giant=1, Supergiant=2).
                 Shape should be (n,)
        """
        # TODO
        preds = []
        for x in X_pred:
            z = np.cos(x ** 2).sum()
            preds.append(1 + np.sign(z) * (np.abs(z) > 0.3))
        return np.array(preds)
    
    def predict_proba(self, X_pred):
        """    
        Predict classification probabilities of points given feature values in X_pred
        
        :param X_pred: a 2D numpy array of (transformed) feature values. Shape is (n x 2)
        :return: a 2D numpy array of predicted class probabilities (Dwarf=index 0, Giant=index 1, Supergiant=index 2).
                 Shape should be (n x 3)
        """
        # TODO
        scores = np.dot(X_pred, self.W.T)
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        return probs
        pass

# %%
class KNNClassifier:
    def __init__(self, k):
        self.X = None
        self.y = None
        self.K = k
        
    def fit(self, X, y):
        """
        In KNN, "fitting" can be as simple as storing the data, so this has been written for you.
        If you'd like to add some preprocessing here without changing the inputs, feel free,
        but this is completely optional.
        """
        self.X = X
        self.y = y

    def predict(self, X_pred):
        """
        The code in this method should be removed and replaced! We included it
        just so that the distribution code is runnable and produces a
        (currently meaningless) visualization.
        
        Predict classes of points given feature values in X_pred
        
        :param X_pred: a 2D numpy array of (transformed) feature values. Shape is (n x 2)
        :return: a 1D numpy array of predicted classes (Dwarf=0, Giant=1, Supergiant=2).
                 Shape should be (n,)
        """
        preds = []
        for x in X_pred:
            distances = np.sum((self.X - x) ** 2, axis=1)
            nearest_indices = np.argsort(distances)[:self.K]
            nearest_labels = self.y[nearest_indices]
            unique_labels, label_counts = np.unique(nearest_labels, return_counts=True)
            pred_label = unique_labels[np.argmax(label_counts)]
            preds.append(pred_label)
        return np.array(preds)

# %%
def phi(X):
    """
    Transform [x_1, x_2] into basis [ln(x_1 + 10), x_2^2]

    :param t: a 2D numpy array of values to transform. Shape is (n x 2)
    :return: a 2D array in which each row corresponds to a basis transformation of
             an input value. Shape should be (n x 2)
    """
    # TODO
    transformed_X = np.zeros((X.shape[0], 2))
    transformed_X[:, 0] = np.log(X[:, 0] + 10)
    transformed_X[:, 1] = X[:, 1] ** 2
    return transformed_X

# %% [markdown]
# ## Plotting Function for Problem 3, Subpart 1

# %%
# Visualize the decision boundary that a model produces
def visualize_boundary(model, X, y, title, basis=None, width=2):
    # Create a grid of points
    x_min, x_max = min(X[:, 0] - width), max(X[:, 0] + width)
    y_min, y_max = min(X[:, 1] - width), max(X[:, 1] + width)
    xx, yy = np.meshgrid(
        np.arange(x_min, x_max, 0.05),
        np.arange(y_min, y_max, 0.05)
    )

    # Flatten the grid so the values match spec for self.predict
    xx_flat = xx.flatten()
    yy_flat = yy.flatten()
    X_pred = np.vstack((xx_flat, yy_flat)).T
    
    if basis is not None:
        X_pred = basis(X_pred)

    # Get the class predictions
    Y_hat = model.predict(X_pred)
    Y_hat = Y_hat.reshape((xx.shape[0], xx.shape[1]))

    # Visualize them.
    cmap = c.ListedColormap(['r', 'b', 'g'])
    plt.figure()
    plt.title(title)
    plt.xlabel('Magnitude')
    plt.ylabel('Temperature')
    plt.pcolormesh(xx, yy, Y_hat, cmap=cmap, alpha=0.3)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, linewidths=1,
                edgecolors='black')

    # Adding a legend and a title
    red = mpatches.Patch(color='red', label='Dwarf')
    blue = mpatches.Patch(color='blue', label='Giant')
    green = mpatches.Patch(color='green', label='Supergiant')
    plt.legend(handles=[red, blue, green])

    # Saving the image to a file, and showing it as well
    plt.savefig(title + '.png')
    plt.show()

# %% [markdown]
# ## Problem 3, Subpart 1

# %%
gaussian_shared = GaussianGenerativeModel(is_shared_covariance=True)
gaussian_shared.fit(X_stars, y_stars)
visualize_boundary(model=gaussian_shared,
                   X=X_stars,
                   y=y_stars,
                   title='gaussian_generative_shared_covariance',
                   basis=None)

# %%
gaussian_separate = GaussianGenerativeModel(is_shared_covariance=False)
gaussian_separate.fit(X_stars, y_stars)
visualize_boundary(model=gaussian_separate,
                   X=X_stars,
                   y=y_stars,
                   title='gaussian_generative_separate_covariance',
                   basis=None)

# %%
knn_1 = KNNClassifier(k=1)
knn_1.fit(X_stars, y_stars)
visualize_boundary(model=knn_1,
                   X=X_stars,
                   y=y_stars,
                   title='knn_k1',
                   basis=None)

# %%
knn_5 = KNNClassifier(k=5)
knn_5.fit(X_stars, y_stars)
visualize_boundary(model=knn_5,
                   X=X_stars,
                   y=y_stars,
                   title='knn_k5',
                   basis=None)

# %%
softmax_regression_with_feature_map = SoftmaxRegression(eta=0.001, lam=0.001)
softmax_regression_with_feature_map.fit(X_stars, y_stars)

visualize_boundary(model=softmax_regression_with_feature_map,
                   X=X_stars,
                   y=y_stars,
                   title='softmax_regression_with_feature_map',
                   basis=phi)

# %%
# Example of fitting a model and visualizing the decision boundaries;
# do this for each of the four models
softmax_model = SoftmaxRegression(eta=0.001, lam=0.001)
softmax_model.fit(X_stars, y_stars)
visualize_boundary(model=softmax_model,
                   X=X_stars,
                   y=y_stars,
                   title='softmax_regression_result',
                   basis=None)

# %%
# Define the point to test
test_point = np.array([[3, -2]])
# Define class labels
class_labels = ['Dwarf', 'Giant', 'Supergiant']

# Test the point with Gaussian Generative Models
category_gaussian_shared = gaussian_shared.predict(test_point)
category_gaussian_separate = gaussian_separate.predict(test_point)

print("Gaussian Generative Model (Shared Covariance):", class_labels[category_gaussian_shared[0]])
print("Gaussian Generative Model (Separate Covariance):", class_labels[category_gaussian_separate[0]])

softmax_regression = SoftmaxRegression(eta=0.001, lam=0.001)
softmax_regression.fit(X_stars, y_stars)
category_softmax = np.argmax(softmax_regression.predict_proba(test_point), axis=1)

softmax_regression_with_feature_map = SoftmaxRegression(eta=0.001, lam=0.001)
X_stars_mapped = phi(X_stars)
softmax_regression_with_feature_map.fit(X_stars_mapped, y_stars)

# Test the point with Softmax Regression with Feature Map
test_point_mapped = phi(test_point)
category_softmax_feature_map = np.argmax(softmax_regression_with_feature_map.predict_proba(test_point_mapped), axis=1)

print("Softmax Regression:", class_labels[category_softmax[0]])
print("Softmax Regression with Feature Map:", class_labels[category_softmax_feature_map[0]])

# Test the point with kNN Classifier
category_knn_1 = knn_1.predict(test_point)

print("kNN Classifier (k=1):", class_labels[category_knn_1[0]])
# Out:
# Gaussian Generative Model (Shared Covariance): Dwarf
# Gaussian Generative Model (Separate Covariance): Dwarf
# Softmax Regression: Dwarf
# Softmax Regression with Feature Map: Supergiant
# kNN Classifier (k=1): Dwarf

# %%
# test your models by passing your fitted models into the functions below
# softmax_model is an instance of class SoftmaxRegression fitted to data X_stars, y_stars
# basis_model is an instance of class SoftmaxRegression fitted to data phi(X_stars), y_stars
# knn1_model is an instance of class KNNClassifier with parameter k=1
# knn5_model is an instance of class KNNClassifier with parameter k=5
test_p3_softmax(softmax_model, basis_model)
test_p3_knn(knn1_model, knn5_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[364], line 6
#       1 # test your models by passing your fitted models into the functions below
#       2 # softmax_model is an instance of class SoftmaxRegression fitted to data X_stars, y_stars
#       3 # basis_model is an instance of class SoftmaxRegression fitted to data phi(X_stars), y_stars
#       4 # knn1_model is an instance of class KNNClassifier with parameter k=1
#       5 # knn5_model is an instance of class KNNClassifier with parameter k=5
# ----> 6 test_p3_softmax(softmax_model, basis_model)
#       7 test_p3_knn(knn1_model, knn5_model)
#
# NameError: name 'basis_model' is not defined
